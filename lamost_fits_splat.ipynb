# %%
from astropy.io import fits

# %%
import numpy

# %%
# %matplotlib inline

# %%
file='/home/skoda/LAMOST/BUG-in_SPLAT/spec-56769-HD184250N365730V_sp16-027.fits'

# %%
hdulist=fits.open(file)

# %%
header=hdulist[0].header

# %%
crpix1=header['CRPIX1']
crval1=header['CRVAL1']
cdelt1=header['CD1_1']
naxis1=header['NAXIS1']

# %%
print crpix1,crval1,cdelt1,naxis1
# Out:
# 1 3.5682 0.0001 3909

# %%
pixaxis=numpy.arange(naxis1)

# %%
print pixaxis
# Out:
# [   0    1    2 ... 3906 3907 3908]

# %%
xaxis=cdelt1*pixaxis+crval1

# %%
wavelen=10**xaxis

# %%
print xaxis
# Out:
# [3.5682 3.5683 3.5684 ... 3.9588 3.9589 3.959 ]

# %%
print wavelen
# Out:
# [3699.98531173 3700.83736292 3701.68961033 ... 9094.94338555 9097.03781478
#  9099.13272632]

# %%
print header['FILENAME']
# Out:
# spec-56769-HD184250N365730V_sp16-027.fits

# %%
data0=hdulist[0].data[0]

# %%
data1=hdulist[0].data[1]

# %%
data2=hdulist[0].data[2]

# %%
data3=hdulist[0].data[3]

# %%
data4=hdulist[0].data[4]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(xaxis,data0)

# %%
plt.plot(xaxis,data1)

# %%
plt.plot(xaxis,data2)

# %%
plt.plot(xaxis,data3)

# %%
plt.plot(xaxis,data4)

# %%
plt.plot(xaxis,(data0+data1+data2+data3+data4)/5.0)

# %%
'''The main shape is caused by line data2 which is in DR2 the linear array of wavelengths in A (unlike DR1 where it was continuum normalized flux with some quirks)'''
# Out:
# 'The main shape is caused by line data2 which is in DR2 the linear array of wavelengths in A (unlike DR1 where it was continuum normalized flux with some quirks)'
